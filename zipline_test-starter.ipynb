# %% [markdown]
# # Zipline Installation: Bundle Ingest & Algorithm Test

# %% [markdown]
# ## Imports and Settings

# %% [markdown]
# We don't need much here since the imports all take place in the cell where we formulate the algorithm.
#
# https://zipline.ml4trading.io/beginner-tutorial.html

# %%
# %matplotlib inline
import pandas as pd
from zipline.api import order, record, symbol
import os

# %%
#pathways and api_key
buyapple_path = open("buy_apple_path.txt").read()
quandl_api_key_text = open("quandl_api_key_text.txt").read()

# %%
# !zipline run -f {buyapple_path} --start 2016-1-1 --end 2018-1-1 -o buyapple_out.pickle --no-benchmark
# Out:
# Figure(1800x800)
# [2023-03-26 04:26:39.074160] INFO: zipline.finance.metrics.tracker: Simulated 503 trading days
# first open: 2016-01-04 14:31:00+00:00
# last close: 2017-12-29 21:00:00+00:00

# %%
import pandas as pd
perf = pd.read_pickle('buyapple_out.pickle')
perf.head()
# Out:
#                                         period_open              period_close  \
# 2016-01-04 21:00:00+00:00 2016-01-04 14:31:00+00:00 2016-01-04 21:00:00+00:00
# 2016-01-05 21:00:00+00:00 2016-01-05 14:31:00+00:00 2016-01-05 21:00:00+00:00
# 2016-01-06 21:00:00+00:00 2016-01-06 14:31:00+00:00 2016-01-06 21:00:00+00:00
# 2016-01-07 21:00:00+00:00 2016-01-07 14:31:00+00:00 2016-01-07 21:00:00+00:00
# 2016-01-08 21:00:00+00:00 2016-01-08 14:31:00+00:00 2016-01-08 21:00:00+00:00
#
#                            shorts_count  long_value  short_value   pnl  \
# 2016-01-04 21:00:00+00:00             0         0.0          0.0   0.0
# 2016-01-05 21:00:00+00:00             0      1027.1          0.0  -1.0
# 2016-01-06 21:00:00+00:00             0      2014.0          0.0 -21.1
# 2016-01-07 21:00:00+00:00             0      2893.5          0.0 -86.0
# 2016-01-08 21:00:00+00:00             0      3878.4          0.0  14.3
#
#                            capital_used  long_exposure  \
# ...

# %%
# %pylab inline
figsize(12, 12)
import matplotlib.pyplot as plt

ax1 = plt.subplot(211)
perf.portfolio_value.plot(ax=ax1)
ax1.set_ylabel('Portfolio Value')
ax2 = plt.subplot(212, sharex=ax1)
perf.AAPL.plot(ax=ax2)
ax2.set_ylabel('AAPL Stock Price')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\Users\wche7\miniconda3\envs\liveproject\lib\site-packages\IPython\core\magics\pylab.py:160: UserWarning: pylab import has clobbered these variables: ['record']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"
# Text(0, 0.5, 'AAPL Stock Price')

# %% [markdown]
# ## Load Zipline extension

# %%
# %load_ext zipline

# %% [markdown]
# ## Ingest Data

# %%
os.environ['QUANDL_API_KEY']=quandl_api_key_text

# %%
# !zipline ingest -b quandl
# Out:
# ...
# Merging daily equity files:
# [2023-03-26 04:26:47.452075] INFO: zipline.data.bundles.core: Ingesting quandl.
# [2023-03-26 04:26:47.452075] INFO: zipline.data.bundles.quandl: Downloading WIKI metadata.
# [2023-03-26 04:27:26.504113] INFO: zipline.data.bundles.quandl: Parsing raw data.
# [2023-03-26 04:28:11.211427] INFO: zipline.data.bundles.quandl: Generating asset metadata.
# C:\Users\wche7\miniconda3\envs\liveproject\lib\site-packages\zipline\data\bcolz_daily_bars.py:366: UserWarning: Ignoring 1 values because they are out of bounds for uint32:             open  high   low  close        volume  ex_dividend  split_ratio
# 2011-04-11  1.79  1.84  1.55    1.7  6.674913e+09          0.0          1.0
#   winsorise_uint32(raw_data, invalid_data_behavior, "volume", *OHLC)
# [2023-03-26 04:30:49.234876] INFO: zipline.data.bundles.quandl: Parsing split data.
# [2023-03-26 04:30:49.480894] INFO: zipline.data.bundles.quandl: Parsing dividend data.
# ...

# %% [markdown]
# ## Run a simple test algorithm
#
# data.history() is a convenience function that keeps a rolling window of data for you. The first argument is the number of bars you want to collect, the second argument is the unit (either '1d' or '1m', but note that you need to have minute-level data for using 1m).

# %%
# %%zipline --start 2014-1-1 --end 2018-1-1 --no-benchmark -o dma.pickle
#
# from zipline.api import order_target, record, symbol
# import matplotlib.pyplot as plt
#
# def initialize(context):
#     context.i = 0
#     context.asset = symbol('AAPL')
#
#
# def handle_data(context, data):
#     # Skip first 300 days to get full windows
#     context.i += 1
#     if context.i < 300:
#         return
#
#     # Compute averages
#     # data.history() has to be called with the same params
#     # from above and returns a pandas dataframe.
#     short_mavg = data.history(context.asset, 'price', bar_count=100, frequency="1d").mean()
#     long_mavg = data.history(context.asset, 'price', bar_count=300, frequency="1d").mean()
#
#     # Trading logic
#     if short_mavg > long_mavg:
#         # order_target orders as many shares as needed to
#         # achieve the desired number of shares.
#         order_target(context.asset, 1000)
#     elif short_mavg < long_mavg:
#         order_target(context.asset, 0)
#
#     # Save values for later inspection
#     record(AAPL=data.current(context.asset, 'price'),
#            short_mavg=short_mavg,
#            long_mavg=long_mavg)
#
#
# def analyze(context, perf):
#     fig = plt.figure()
#     ax1 = fig.add_subplot(211)
#     perf.portfolio_value.plot(ax=ax1)
#     ax1.set_ylabel('portfolio value in $')
#
#     ax2 = fig.add_subplot(212)
#     perf['AAPL'].plot(ax=ax2)
#     perf[['short_mavg', 'long_mavg']].plot(ax=ax2)
#
#     perf_trans = perf.loc[[t != [] for t in perf.transactions]]
#     buys = perf_trans.loc[[t[0]['amount'] > 0 for t in perf_trans.transactions]]
#     sells = perf_trans.loc[
#         [t[0]['amount'] < 0 for t in perf_trans.transactions]]
#     ax2.plot(buys.index, perf.short_mavg.loc[buys.index],
#              '^', markersize=10, color='m')
#     ax2.plot(sells.index, perf.short_mavg.loc[sells.index],
#              'v', markersize=10, color='k')
#     ax2.set_ylabel('price in $')
#     plt.legend(loc=0)
#     plt.show()
# Out:
#                                         period_open              period_close  \
# 2014-01-02 21:00:00+00:00 2014-01-02 14:31:00+00:00 2014-01-02 21:00:00+00:00
# 2014-01-03 21:00:00+00:00 2014-01-03 14:31:00+00:00 2014-01-03 21:00:00+00:00
# 2014-01-06 21:00:00+00:00 2014-01-06 14:31:00+00:00 2014-01-06 21:00:00+00:00
# 2014-01-07 21:00:00+00:00 2014-01-07 14:31:00+00:00 2014-01-07 21:00:00+00:00
# 2014-01-08 21:00:00+00:00 2014-01-08 14:31:00+00:00 2014-01-08 21:00:00+00:00
# ...                                             ...                       ...
# 2017-12-22 21:00:00+00:00 2017-12-22 14:31:00+00:00 2017-12-22 21:00:00+00:00
# 2017-12-26 21:00:00+00:00 2017-12-26 14:31:00+00:00 2017-12-26 21:00:00+00:00
# 2017-12-27 21:00:00+00:00 2017-12-27 14:31:00+00:00 2017-12-27 21:00:00+00:00
# 2017-12-28 21:00:00+00:00 2017-12-28 14:31:00+00:00 2017-12-28 21:00:00+00:00
# 2017-12-29 21:00:00+00:00 2017-12-29 14:31:00+00:00 2017-12-29 21:00:00+00:00
#
# ...
